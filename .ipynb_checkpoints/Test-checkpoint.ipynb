# %%
import torch
import pickle
import random
import pandas as pd
import numpy as np

import main_classificaiton as mc

# %%
# seed 고정
random_seed = 42

torch.manual_seed(random_seed)
torch.cuda.manual_seed(random_seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(random_seed)
random.seed(random_seed)

# %%
# Case 1. LSTM model (w/o data representation)
config1 = {
        'model': 'LSTM', # classification에 활용할 알고리즘 정의, {'LSTM', 'GRU', 'CNN_1D', 'LSTM_FCNs', 'FC'} 중 택 1
        'training': True,  # 학습 여부, 저장된 학습 완료 모델 존재시 False로 설정
        'best_model_path': './ckpt/lstm.pt',  # 학습 완료 모델 저장 경로
        'parameter': {
            'input_size': 9,  # 데이터의 변수 개수, int
            'num_classes': 6,  # 분류할 class 개수, int
            'num_layers': 2,  # recurrent layers의 수, int(default: 2, 범위: 1 이상)
            'hidden_size': 64,  # hidden state의 차원, int(default: 64, 범위: 1 이상)
            'dropout': 0.1,  # dropout 확률, float(default: 0.1, 범위: 0 이상 1 이하)
            'bidirectional': True,  # 모델의 양방향성 여부, bool(default: True)
            'num_epochs': 150,  # 학습 epoch 횟수, int(default: 150, 범위: 1 이상)
            'batch_size': 64,  # batch 크기, int(default: 64, 범위: 1 이상, 컴퓨터 사양에 적합하게 설정)
            'lr': 0.0001,  # learning rate, float(default: 0.001, 범위: 0.1 이하)
            'device': 'cuda'  # 학습 환경, ["cuda", "cpu"] 중 선택
        }
}

# Case 2. GRU model (w/o data representation)
config2 = {
        'model': 'GRU', # classification에 활용할 알고리즘 정의, {'LSTM', 'GRU', 'CNN_1D', 'LSTM_FCNs', 'FC'} 중 택 1
        'training': True,  # 학습 여부, 저장된 학습 완료 모델 존재시 False로 설정
        'best_model_path': './ckpt/gru.pt',  # 학습 완료 모델 저장 경로
        'parameter': {
            'input_size': 9,  # 데이터의 변수 개수, int
            'num_classes': 6,  # 분류할 class 개수, int
            'num_layers': 2,  # recurrent layers의 수, int(default: 2, 범위: 1 이상)
            'hidden_size': 64,  # hidden state의 차원, int(default: 64, 범위: 1 이상)
            'dropout': 0.1,  # dropout 확률, float(default: 0.1, 범위: 0 이상 1 이하)
            'bidirectional': True,  # 모델의 양방향성 여부, bool(default: True)
            'num_epochs': 150,  # 학습 epoch 횟수, int(default: 150, 범위: 1 이상)
            'batch_size': 64,  # batch 크기, int(default: 64, 범위: 1 이상, 컴퓨터 사양에 적합하게 설정)
            'lr': 0.0001,  # learning rate, float(default: 0.001, 범위: 0.1 이하)
            'device': 'cuda'  # 학습 환경, ["cuda", "cpu"] 중 선택
        }
}

# Case 3. CNN_1D model (w/o data representation)
config3 = {
        'model': 'CNN_1D', # classification에 활용할 알고리즘 정의, {'LSTM', 'GRU', 'CNN_1D', 'LSTM_FCNs', 'FC'} 중 택 1
        'training': True,  # 학습 여부, 저장된 학습 완료 모델 존재시 False로 설정
        'best_model_path': './ckpt/cnn_1d.pt',  # 학습 완료 모델 저장 경로
        'parameter': {
            'input_size': 9,  # 데이터의 변수 개수, int
            'num_classes': 6,  # 분류할 class 개수, int
            'seq_len': 128,  # 데이터의 시간 길이, int
            'output_channels': 64, # convolution layer의 output channel, int(default: 64, 범위: 1 이상, 2의 지수로 설정 권장)
            'kernel_size': 3, # convolutional layer의 filter 크기, int(default: 3, 범위: 3 이상, 홀수로 설정 권장)
            'stride': 1, # convolution layer의 stride 크기, int(default: 1, 범위: 1 이상)
            'padding': 0, # padding 크기, int(default: 0, 범위: 0 이상)
            'drop_out': 0.1, # dropout 확률, float(default: 0.1, 범위: 0 이상 1 이하)
            'num_epochs': 150,  # 학습 epoch 횟수, int(default: 150, 범위: 1 이상)
            'batch_size': 64,  # batch 크기, int(default: 64, 범위: 1 이상, 컴퓨터 사양에 적합하게 설정)
            'lr': 0.0001,  # learning rate, float(default: 0.0001, 범위: 0.1 이하)
            'device': 'cuda'  # 학습 환경, ["cuda", "cpu"] 중 선택
        }
}

# Case 4. LSTM_FCNs model (w/o data representation)
config4 = {
        'model': 'LSTM_FCNs', # classification에 활용할 알고리즘 정의, {'LSTM', 'GRU', 'CNN_1D', 'LSTM_FCNs', 'FC'} 중 택 1
        'training': True,  # 학습 여부, 저장된 학습 완료 모델 존재시 False로 설정
        'best_model_path': './ckpt/lstm_fcn.pt',  # 학습 완료 모델 저장 경로
        'parameter': {
            'input_size': 9,  # 데이터의 변수 개수, int
            'num_classes': 6,  # 분류할 class 개수, int
            'num_layers': 1,  # recurrent layers의 수, int(default: 1, 범위: 1 이상)
            'lstm_drop_out': 0.4, # LSTM dropout 확률, float(default: 0.4, 범위: 0 이상 1 이하)
            'fc_drop_out': 0.1, # FC dropout 확률, float(default: 0.1, 범위: 0 이상 1 이하)
            'num_epochs': 150, # 학습 epoch 횟수, int(default: 150, 범위: 1 이상)
            'batch_size': 64,  # batch 크기, int(default: 64, 범위: 1 이상, 컴퓨터 사양에 적합하게 설정)
            'lr': 0.0001,  # learning rate, float(default: 0.0001, 범위: 0.1 이하)
            'device': 'cuda'  # 학습 환경, ["cuda", "cpu"] 중 선택
        }
}

# Case 5. fully-connected layers (w/ data representation)
config5 = {
        'model': 'FC', # classification에 활용할 알고리즘 정의, {'LSTM', 'GRU', 'CNN_1D', 'LSTM_FCNs', 'FC'} 중 택 1
        "training": True,  # 학습 여부, 저장된 학습 완료 모델 존재시 False로 설정
        "best_model_path": './ckpt/fc.pt',  # 학습 완료 모델 저장 경로
        'parameter': {
            'input_size': 64,  # 데이터의 변수 개수(representation 차원), int
            'num_classes': 6,  # 분류할 class 개수, int
            'drop_out': 0.1, # dropout 확률, float(default: 0.1, 범위: 0 이상 1 이하)
            'bias': True, # bias 사용 여부, bool(default: True)
            'num_epochs': 150, # 학습 epoch 횟수, int(default: 150, 범위: 1 이상)
            'batch_size': 64,  # batch 크기, int(default: 64, 범위: 1 이상, 컴퓨터 사양에 적합하게 설정)
            'lr': 0.0001,  # learning rate, float(default: 0.0001, 범위: 0.1 이하)
            'device': 'cuda'  # 학습 환경, ["cuda", "cpu"] 중 선택
        }
}

# %%
# raw time series data
train_x = pickle.load(open('./data/x_train.pkl', 'rb'))
train_y = pickle.load(open('./data/y_train.pkl', 'rb'))
test_x = pickle.load(open('./data/x_test.pkl', 'rb'))
test_y = pickle.load(open('./data/y_test.pkl', 'rb'))

train_data = {'x': train_x, 'y': train_y}
test_data = {'x': test_x, 'y': test_y}

print(train_x.shape)  #shape : (num_of_instance x input_dims x window_size) = (7352, 9, 128)
print(train_y.shape) #shape : (num_of_instance) = (7352, )
print(test_x.shape)  #shape : (num_of_instance x input_dims x window_size) = (2947, 9, 128)
print(test_y.shape)  #shape : (num_of_instance) = (2947, )
# Out:
# (7352, 9, 128)
# (7352,)
# (2947, 9, 128)
# (2947,)

# %%
# Case 1. LSTM model (w/o data representation)
config = config1
data_cls = mc.Classification(config, train_data, test_data)
model = data_cls.build_model()  # 모델 구축

if config["training"]:
    best_model = data_cls.train_model(model)  # 모델 학습
    data_cls.save_model(best_model, best_model_path=config["best_model_path"])  # 모델 저장

pred, prob, acc = data_cls.pred_data(model, best_model_path=config["best_model_path"])  # class 예측
# Out:
# Start training model
#
# Epoch 1/150
# train Loss: 1.7789 Acc: 0.2663
# val Loss: 1.7555 Acc: 0.3569
#
# Epoch 10/150
# train Loss: 0.9436 Acc: 0.6031
# val Loss: 1.0463 Acc: 0.6003
#
# Epoch 20/150
# train Loss: 0.7743 Acc: 0.6531
# val Loss: 0.7120 Acc: 0.6547
#
# Epoch 30/150
# train Loss: 0.5467 Acc: 0.7507
# val Loss: 0.6013 Acc: 0.7267
#
# Epoch 40/150
# train Loss: 0.4847 Acc: 0.7808
# val Loss: 0.5445 Acc: 0.7403
#
# Epoch 50/150
# train Loss: 0.4123 Acc: 0.8175
# val Loss: 0.5333 Acc: 0.7539
#
# Epoch 60/150
# train Loss: 0.3594 Acc: 0.8381
# val Loss: 0.4361 Acc: 0.8076
#
# Epoch 70/150
# train Loss: 0.3098 Acc: 0.8641
# val Loss: 0.4221 Acc: 0.8416
#
# Epoch 80/150
# train Loss: 0.3066 Acc: 0.8670
# val Loss: 0.4137 Acc: 0.8436
#
# Epoch 90/150
# train Loss: 0.1709 Acc: 0.9337
# val Loss: 0.3896 Acc: 0.8919
#
# Epoch 100/150
# train Loss: 0.1159 Acc: 0.9529
# val Loss: 0.2432 Acc: 0.9245
#
# Epoch 110/150
# train Loss: 0.0949 Acc: 0.9597
# val Loss: 0.2484 Acc: 0.9245
#
# Epoch 120/150
# train Loss: 0.0891 Acc: 0.9609
# val Loss: 0.2535 Acc: 0.9266
#
# Epoch 130/150
# train Loss: 0.0846 Acc: 0.9612
# val Loss: 0.3684 Acc: 0.8967
#
# Epoch 140/150
# train Loss: 0.0813 Acc: 0.9599
# val Loss: 0.4052 Acc: 0.8933
#
# Epoch 150/150
# train Loss: 0.0752 Acc: 0.9650
# val Loss: 0.4057 Acc: 0.9096
#
# Training complete in 6m 31s
# Best val Acc: 0.931339
#
# Start testing data

# %%
print(acc)
print(pred.shape, prob.shape)
# Out:
# 0.8941296233457754
# (2947,) (2947, 6)

# %%
# Case 2. GRU (w/o data representation)
config = config2
data_cls = mc.Classification(config, train_data, test_data)
model = data_cls.build_model()  # 모델 구축

if config["training"]:
    best_model = data_cls.train_model(model)  # 모델 학습
    data_cls.save_model(best_model, best_model_path=config["best_model_path"])  # 모델 저장

pred, prob, acc = data_cls.pred_data(model, best_model_path=config["best_model_path"])  # class 예측
# Out:
# Start training model
#
# Epoch 1/150
# train Loss: 1.7381 Acc: 0.2835
# val Loss: 1.6610 Acc: 0.3725
#
# Epoch 10/150
# train Loss: 0.8096 Acc: 0.6638
# val Loss: 0.8608 Acc: 0.6818
#
# Epoch 20/150
# train Loss: 0.4128 Acc: 0.8085
# val Loss: 0.5337 Acc: 0.8063
#
# Epoch 30/150
# train Loss: 0.3279 Acc: 0.8718
# val Loss: 0.4943 Acc: 0.8627
#
# Epoch 40/150
# train Loss: 0.1800 Acc: 0.9427
# val Loss: 0.2411 Acc: 0.9375
#
# Epoch 50/150
# train Loss: 0.1488 Acc: 0.9437
# val Loss: 0.2284 Acc: 0.9354
#
# Epoch 60/150
# train Loss: 0.1335 Acc: 0.9476
# val Loss: 0.2221 Acc: 0.9368
#
# Epoch 70/150
# train Loss: 0.1150 Acc: 0.9526
# val Loss: 0.2192 Acc: 0.9361
#
# Epoch 80/150
# train Loss: 0.1056 Acc: 0.9563
# val Loss: 0.2118 Acc: 0.9395
#
# Epoch 90/150
# train Loss: 0.1030 Acc: 0.9577
# val Loss: 0.2146 Acc: 0.9375
#
# Epoch 100/150
# train Loss: 0.0997 Acc: 0.9572
# val Loss: 0.2128 Acc: 0.9388
#
# Epoch 110/150
# train Loss: 0.0996 Acc: 0.9577
# val Loss: 0.2076 Acc: 0.9347
#
# Epoch 120/150
# train Loss: 0.0950 Acc: 0.9619
# val Loss: 0.2135 Acc: 0.9368
#
# Epoch 130/150
# train Loss: 0.0906 Acc: 0.9624
# val Loss: 0.2229 Acc: 0.9361
#
# Epoch 140/150
# train Loss: 0.0899 Acc: 0.9631
# val Loss: 0.2185 Acc: 0.9354
#
# Epoch 150/150
# train Loss: 0.0888 Acc: 0.9657
# val Loss: 0.2181 Acc: 0.9368
#
# Training complete in 6m 16s
# Best val Acc: 0.942216
#
# Start testing data

# %%
print(acc)
print(pred.shape, prob.shape)
# Out:
# 0.8866644044791314
# (2947,) (2947, 6)

# %%
# Case 3. CNN_1D (w/o data representation)
config = config3
data_cls = mc.Classification(config, train_data, test_data)
model = data_cls.build_model()  # 모델 구축

if config["training"]:
    best_model = data_cls.train_model(model)  # 모델 학습
    data_cls.save_model(best_model, best_model_path=config["best_model_path"])  # 모델 저장

pred, prob, acc = data_cls.pred_data(model, best_model_path=config["best_model_path"])  # class 예측
# Out:
# Start training model
#
# Epoch 1/150
# train Loss: 1.6918 Acc: 0.4613
# val Loss: 1.5259 Acc: 0.6254
#
# Epoch 10/150
# train Loss: 0.3604 Acc: 0.8718
# val Loss: 0.6172 Acc: 0.8205
#
# Epoch 20/150
# train Loss: 0.2390 Acc: 0.9170
# val Loss: 0.5592 Acc: 0.8668
#
# Epoch 30/150
# train Loss: 0.1722 Acc: 0.9398
# val Loss: 0.4931 Acc: 0.9001
#
# Epoch 40/150
# train Loss: 0.1328 Acc: 0.9519
# val Loss: 0.4599 Acc: 0.9075
#
# Epoch 50/150
# train Loss: 0.1099 Acc: 0.9585
# val Loss: 0.4441 Acc: 0.9103
#
# Epoch 60/150
# train Loss: 0.0975 Acc: 0.9602
# val Loss: 0.4169 Acc: 0.9075
#
# Epoch 70/150
# train Loss: 0.0872 Acc: 0.9629
# val Loss: 0.4007 Acc: 0.9130
#
# Epoch 80/150
# train Loss: 0.0805 Acc: 0.9645
# val Loss: 0.3797 Acc: 0.9123
#
# Epoch 90/150
# train Loss: 0.0755 Acc: 0.9646
# val Loss: 0.3544 Acc: 0.9137
#
# Epoch 100/150
# train Loss: 0.0728 Acc: 0.9651
# val Loss: 0.3624 Acc: 0.9225
#
# Epoch 110/150
# train Loss: 0.0686 Acc: 0.9668
# val Loss: 0.3752 Acc: 0.9245
#
# Epoch 120/150
# train Loss: 0.0635 Acc: 0.9694
# val Loss: 0.3829 Acc: 0.9252
#
# Epoch 130/150
# train Loss: 0.0616 Acc: 0.9721
# val Loss: 0.3786 Acc: 0.9259
#
# Epoch 140/150
# train Loss: 0.0586 Acc: 0.9728
# val Loss: 0.3943 Acc: 0.9266
#
# Epoch 150/150
# train Loss: 0.0579 Acc: 0.9725
# val Loss: 0.4244 Acc: 0.9259
#
# Training complete in 1m 38s
# Best val Acc: 0.927940
#
# Start testing data

# %%
print(acc)
print(pred.shape, prob.shape)
# Out:
# 0.9036308109942315
# (2947,) (2947, 6)

# %%
# Case 4. LSTM_FCNs (w/o data representation)
config = config4
data_cls = mc.Classification(config, train_data, test_data)
model = data_cls.build_model()  # 모델 구축

if config["training"]:
    best_model = data_cls.train_model(model)  # 모델 학습
    data_cls.save_model(best_model, best_model_path=config["best_model_path"])  # 모델 저장

pred, prob, acc = data_cls.pred_data(model, best_model_path=config["best_model_path"])  # class 예측
# Out:
# Start training model
#
# Epoch 1/150
# train Loss: 1.5299 Acc: 0.5788
# val Loss: 1.4088 Acc: 0.6234
#
# Epoch 10/150
# train Loss: 0.6156 Acc: 0.8956
# val Loss: 0.7001 Acc: 0.8722
#
# Epoch 20/150
# train Loss: 0.2491 Acc: 0.9597
# val Loss: 0.4232 Acc: 0.9021
#
# Epoch 30/150
# train Loss: 0.1551 Acc: 0.9633
# val Loss: 0.3910 Acc: 0.9123
#
# Epoch 40/150
# train Loss: 0.1105 Acc: 0.9651
# val Loss: 0.3644 Acc: 0.9062
#
# Epoch 50/150
# train Loss: 0.0841 Acc: 0.9702
# val Loss: 0.3607 Acc: 0.9211
#
# Epoch 60/150
# train Loss: 0.0720 Acc: 0.9711
# val Loss: 0.3465 Acc: 0.9150
#
# Epoch 70/150
# train Loss: 0.0648 Acc: 0.9731
# val Loss: 0.3626 Acc: 0.9014
#
# Epoch 80/150
# train Loss: 0.0620 Acc: 0.9745
# val Loss: 0.3803 Acc: 0.9157
#
# Epoch 90/150
# train Loss: 0.0595 Acc: 0.9738
# val Loss: 0.3367 Acc: 0.9225
#
# Epoch 100/150
# train Loss: 0.0508 Acc: 0.9770
# val Loss: 0.3713 Acc: 0.9177
#
# Epoch 110/150
# train Loss: 0.0519 Acc: 0.9765
# val Loss: 0.3607 Acc: 0.9211
#
# Epoch 120/150
# train Loss: 0.0482 Acc: 0.9796
# val Loss: 0.4219 Acc: 0.9232
#
# Epoch 130/150
# train Loss: 0.0459 Acc: 0.9804
# val Loss: 0.3856 Acc: 0.9245
#
# Epoch 140/150
# train Loss: 0.0498 Acc: 0.9764
# val Loss: 0.3319 Acc: 0.9171
#
# Epoch 150/150
# train Loss: 0.0435 Acc: 0.9808
# val Loss: 0.4127 Acc: 0.9164
#
# Training complete in 5m 2s
# Best val Acc: 0.927260
#
# Start testing data

# %%
print(acc)
print(pred.shape, prob.shape)
# Out:
# 0.9321343739395996
# (2947,) (2947, 6)

# %% [markdown]
# --------------------------------------------------

# %%
# representation data
train_x = pd.read_csv('./data/ts2vec_repr_train.csv')
train_y = pickle.load(open('./data/y_train.pkl', 'rb'))

test_x = pd.read_csv('./data/ts2vec_repr_test.csv')
test_y = pickle.load(open('./data/y_test.pkl', 'rb'))

train_data = {'x': train_x, 'y': train_y}
test_data = {'x': test_x, 'y': test_y}

print(train_x.shape)  #shape : (num_of_instance x representation_dims) = (7352, 64)
print(train_y.shape) #shape : (num_of_instance) = (7352, )
print(test_x.shape)  #shape : (num_of_instance x representation_dims) = (2947, 64)
print(test_y.shape)  #shape : (num_of_instance) = (2947, )
# Out:
# (7352, 64)
# (7352,)
# (2947, 64)
# (2947,)

# %%
# Case 5. fully-connected layers (w/ data representation)
config = config5
data_cls = mc.Classification(config, train_data, test_data)
model = data_cls.build_model()  # 모델 구축

if config["training"]:
    best_model = data_cls.train_model(model)  # 모델 학습
    data_cls.save_model(best_model, best_model_path=config["best_model_path"])  # 모델 저장

pred, prob, acc = data_cls.pred_data(model, best_model_path=config["best_model_path"])  # class 예측
# Out:
# Start training model
#
# Epoch 1/150
# train Loss: 1.7093 Acc: 0.3414
# val Loss: 1.6546 Acc: 0.4092
#
# Epoch 10/150
# train Loss: 0.7202 Acc: 0.7812
# val Loss: 0.7294 Acc: 0.7893
#
# Epoch 20/150
# train Loss: 0.4063 Acc: 0.8978
# val Loss: 0.4690 Acc: 0.8858
#
# Epoch 30/150
# train Loss: 0.2788 Acc: 0.9250
# val Loss: 0.3512 Acc: 0.8994
#
# Epoch 40/150
# train Loss: 0.2171 Acc: 0.9378
# val Loss: 0.2951 Acc: 0.9055
#
# Epoch 50/150
# train Loss: 0.1794 Acc: 0.9429
# val Loss: 0.2678 Acc: 0.9069
#
# Epoch 60/150
# train Loss: 0.1563 Acc: 0.9490
# val Loss: 0.2534 Acc: 0.9089
#
# Epoch 70/150
# train Loss: 0.1426 Acc: 0.9512
# val Loss: 0.2471 Acc: 0.9123
#
# Epoch 80/150
# train Loss: 0.1323 Acc: 0.9510
# val Loss: 0.2410 Acc: 0.9177
#
# Epoch 90/150
# train Loss: 0.1212 Acc: 0.9544
# val Loss: 0.2384 Acc: 0.9239
#
# Epoch 100/150
# train Loss: 0.1170 Acc: 0.9539
# val Loss: 0.2366 Acc: 0.9293
#
# Epoch 110/150
# train Loss: 0.1127 Acc: 0.9575
# val Loss: 0.2385 Acc: 0.9313
#
# Epoch 120/150
# train Loss: 0.1091 Acc: 0.9570
# val Loss: 0.2396 Acc: 0.9327
#
# Epoch 130/150
# train Loss: 0.1048 Acc: 0.9590
# val Loss: 0.2414 Acc: 0.9313
#
# Epoch 140/150
# train Loss: 0.1019 Acc: 0.9600
# val Loss: 0.2424 Acc: 0.9334
#
# Epoch 150/150
# train Loss: 0.0986 Acc: 0.9609
# val Loss: 0.2459 Acc: 0.9341
#
# Training complete in 0m 56s
# Best val Acc: 0.934738
#
# Start testing data

# %%
print(acc)
print(pred.shape, prob.shape)
# Out:
# 0.9168646080760096
# (2947,) (2947, 6)
